# %%
# %%html
# <style>
#     h1 {color:darkblue}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, limegreen, deepskyblue, limegreen);
#     }
# </style>
# Out:
# <style>
#     body {font-size:1.2em}
#     h1 {color:darkblue}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, limegreen, deepskyblue, limegreen);
#     }
# </style>

# %% [markdown]
# <img src="./images/OpenAIHeaderSmall.png" width="900" alt=""/>

# %% [markdown]
# ---

# %% [markdown]
# # About Paul Deitel
#
# <img src="./images/paul-deitel.jpg" width="150"><img src="./images/deitellogo.png" width="150">
#
# * CEO, Deitel & Associates, Inc.
# * MIT grad
# * 46 years in computing
# * One of the world’s most experienced programming languages trainers
#     * Teaching to industry, military and academic software developers worldwide since 1992
# * Among the world’s best-selling programming languages book and video authors
#
# ---

# %% [markdown]
# # Deitel Programming Languages, Data Science and AI Content
# Learn more at **https://deitel.com**
# * Python/Python Data Science/AI (**New books and videos under development**)
# * Java (**New books available; still working on the videos**)
# * C++20 (published in 2023)
# * C (no videos for this yet, but I have plans to do them)
# * We also have older books on other topics
# ---

# %% [markdown]
# # Staying in Touch
# <table style="width:100%; border-collapse:collapse; text-align:left; table-layout:auto; font-size:1.2em">
#   <colgroup>
#     <col style="width: auto;">
#     <col style="width: auto;">
#   </colgroup>
#   <tr><td><strong>E-mail:</strong></td><td><a href="mailto:paul@deitel.com">paul@deitel.com</a></td></tr>
#   <tr><td><strong>Website:</strong></td><td><a href="https://deitel.com">https://deitel.com</a></td></tr>
#   <tr><td><strong>Contact us:</strong></td><td><a href="https://deitel.com/contact-us">https://deitel.com/contact-us</a></td></tr>
#   <tr><td><strong>Facebook:</strong></td><td><a href="https://facebook.com/DeitelFan">https://facebook.com/DeitelFan</a></td></tr>
#   <tr><td><strong>Threads:</strong></td><td><a href="https://threads.net/DeitelFan">https://threads.net/DeitelFan</a></td></tr>
#   <tr><td><strong>X:</strong></td><td><a href="https://x.com/deitel">https://x.com/deitel</a></td></tr>
#   <tr><td><strong>LinkedIn:</strong></td><td><a href="https://linkedin.com/company/deitel-&amp;-associates">https://linkedin.com/company/deitel-&amp;-associates</a></td></tr>
#   <tr><td><strong>YouTube:</strong></td><td><a href="https://youtube.com/DeitelTV">https://youtube.com/DeitelTV</a></td></tr>
# </table>
#
# ---

# %% [markdown]
# # Outline
# 0. Intro/Setup
# 1. OpenAI Python APIs & the OpenAI Python SDK
# 2. OpenAI Agents SDK
# 3. OpenAI Codex Desktop App
# 4. Wrap-Up and Additional References¶
# ---

# %% [markdown]
# ## Wrap-Up and Additional References
#
# ---

# %% [markdown]
# # Jensen Huang, NVIDIA
# "The number of engineers, software engineers, is increasing. People talk about AI reducing jobs — complete nonsense. It's causing more software engineers to be hired and the reason for that is very simple. If you can hire a software engineer and you can generate $9 trillion with productive work, why wouldn't you want to hire more software engineers?"
# — June 2026 keynote speech at the Computex conference in Taiwan
#
# ---

# %% [markdown]
# &copy; 2026 by Deitel & Associates, Inc. All Rights Reserved.
